# %% [markdown]
# # **06 Classification dengan KNN (K Nearest Neighboard)**
# - Klasifikasi berbasis KNN merupakan salah satu model dalam machine learning yang memprediksi output berdasarkan kesamaan karakteristik dengan sejumlah tetangga terdekat
# - Model KNN dapat digunakan untuk tugas klasifikasi maupun regresi
#
# Referensi : <a href="https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm">Wikipedia</a>

# %% [markdown]
# **Sample Dataset**

# %%
import pandas as pd

sensus = {
    'tinggi': [158, 170, 183, 191, 155, 163, 180, 158, 178],
    'berat': [64, 86, 84, 80, 49, 59, 67, 54, 67],
    'jk': [
        'pria', 'pria', 'pria', 'pria', 'wanita', 'wanita', 'wanita', 'wanita',
        'wanita'
    ]
}

sensus_df = pd.DataFrame(sensus)
sensus_df
# Out:
#    tinggi  berat      jk
# 0     158     64    pria
# 1     170     86    pria
# 2     183     84    pria
# 3     191     80    pria
# 4     155     49  wanita
# 5     163     59  wanita
# 6     180     67  wanita
# 7     158     54  wanita
# 8     178     67  wanita

# %% [markdown]
# **Visualisasi Data**
# - Menggunakan subplots untuk membuat visualisasi data, kemudian melakukan loop pada sensus_df dengan mengelompokkan berdasarkan jenis kelamin (jk) dan menghasilkan 2 output
# - Fungsi scatter() digunakan di sini dengan 2 argumen, di mana argumen pertama adalah sumbu x dan argumen kedua adalah sumbu y

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
for jk, d in sensus_df.groupby('jk'):
    ax.scatter(d['tinggi'], d['berat'], label=jk)

plt.legend(loc='upper left')
plt.title('Sebaran Data Tinggi Badan, Berat Badan, dan Jenis Kelamin')
plt.xlabel('Tinggi Badan (cm)')
plt.ylabel('Berat Badan (kg)')
plt.grid(True)
plt.show()

# %% [markdown]
# **Classification dengan KNN**

# %% [markdown]
# Preprocessing Dataset
# - Fungsi np.array() digunakan untuk mengelompokkan fitur-fitur dan target dari sensus_df menjadi set pelatihan
# - Fungsi LabelBinarizer().fit_transform() digunakan untuk mengubah nilai-nilai string menjadi nilai-nilai biner
# - Setelah nilai-nilai Y diubah menjadi biner, kemudian diubah menjadi array satu dimensi menggunakan fungsi flatten()

# %%
import numpy as np

X_train = np.array(sensus_df[['tinggi', 'berat']])
y_train = np.array(sensus_df['jk'])

print(f'X_train:\n{X_train}\n')
print(f'y_train: {y_train}')
# Out:
# X_train:
# [[158  64]
#  [170  86]
#  [183  84]
#  [191  80]
#  [155  49]
#  [163  59]
#  [180  67]
#  [158  54]
#  [178  67]]
#
# y_train: ['pria' 'pria' 'pria' 'pria' 'wanita' 'wanita' 'wanita' 'wanita' 'wanita']

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
print(f'y_train:\n{y_train}')
# Out:
# y_train:
# [[0]
#  [0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]
#  [1]]

# %%
y_train = y_train.flatten()
print(f'y_train: {y_train}')
# Out:
# y_train: [0 0 0 0 1 1 1 1 1]

# %% [markdown]
# **Training KNN Classification Model**
# - Membuat object KNN dengan nilai neighborsnya 3 dan ditraining menggunakan fungsi fit()

# %%
from sklearn.neighbors import KNeighborsClassifier

K = 3
model = KNeighborsClassifier(n_neighbors=K)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# **Prediksi Jenis Kelamin**
# - Dengan membuat array 2 dimensi menggunakan fungsi reshape() yang berisi nilai tinggi badan dan berat badan beserta nilai prediksi target dari nilai features kemudian mengembalikan nilai yang sebelumnya telah diubah menjadi biner menjadu string kembali menggunakan fungsi inverse_transform()

# %%
tinggi_badan = 155
berat_badan = 70
X_new = np.array([tinggi_badan, berat_badan]).reshape(1, -1)
X_new
# Out:
# array([[155,  70]])

# %%
y_new = model.predict(X_new)
y_new
# Out:
# array([1])

# %%
lb.inverse_transform(y_new)
# Out:
# array(['wanita'], dtype='<U6')

# %% [markdown]
# **Visualisasi Nearest Neighbours**

# %%
fig, ax = plt.subplots()
for jk, d in sensus_df.groupby('jk'):
    ax.scatter(d['tinggi'], d['berat'], label=jk)

plt.scatter(tinggi_badan,
            berat_badan,
            marker='s',
            color='red',
            label='misterius')

plt.legend(loc='upper left')
plt.title('Sebaran Data Tinggi Badan, Berat Badan, dan Jenis Kelamin')
plt.xlabel('Tinggi Badan (cm)')
plt.ylabel('Berat Badan (kg)')
plt.grid(True)
plt.show()

# %% [markdown]
# **Kalkulasi Distance (Euclidean Distance)**

# %% [markdown]
# ![Screenshot 2025-05-30 175034.png](attachment:17989ca0-6d8c-4018-bcfd-cdfcc5aa63ae.png)

# %% [markdown]
# Referensi : <a href="https://en.wikipedia.org/wiki/Euclidean_distance">Wikipedia</a>

# %%
misterius = np.array([tinggi_badan, berat_badan])
misterius
# Out:
# array([155,  70])

# %%
X_train
# Out:
# array([[158,  64],
#        [170,  86],
#        [183,  84],
#        [191,  80],
#        [155,  49],
#        [163,  59],
#        [180,  67],
#        [158,  54],
#        [178,  67]], dtype=int64)

# %%
from scipy.spatial.distance import euclidean

data_jarak = [euclidean(misterius, d) for d in X_train]
data_jarak
# Out:
# [6.708203932499369,
#  21.93171219946131,
#  31.304951684997057,
#  37.36308338453881,
#  21.0,
#  13.601470508735444,
#  25.179356624028344,
#  16.278820596099706,
#  23.194827009486403]

# %%
sensus_df['jarak'] = data_jarak
sensus_df.sort_values(['jarak'])
# Out:
#    tinggi  berat      jk      jarak
# 0     158     64    pria   6.708204
# 5     163     59  wanita  13.601471
# 7     158     54  wanita  16.278821
# 4     155     49  wanita  21.000000
# 1     170     86    pria  21.931712
# 8     178     67  wanita  23.194827
# 6     180     67  wanita  25.179357
# 2     183     84    pria  31.304952
# 3     191     80    pria  37.363083

# %% [markdown]
# **Evaluasi KNN Classification Model**

# %% [markdown]
# Testing Set

# %%
X_test = np.array([[168, 65], [180, 96], [160, 52], [169, 67]])
y_test = lb.transform(np.array(['pria', 'pria', 'wanita', 'wanita'])).flatten()

print(f'X_test:\n{X_test}\n')
print(f'y_test:\n{y_test}')
# Out:
# X_test:
# [[168  65]
#  [180  96]
#  [160  52]
#  [169  67]]
#
# y_test:
# [0 0 1 1]

# %% [markdown]
# **Prediksi terhadap testing set**

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 0, 1, 1])

# %% [markdown]
# Accuracy <br>
# Accuracy is the proportion of test instances that were classified correctly

# %% [markdown]
# ![Screenshot 2025-05-30 175347.png](attachment:539dab86-208b-4c22-80c8-904e28dd3c29.png)

# %% [markdown]
# Referensi : <a href="https://en.wikipedia.org/wiki/Precision_and_recall">Wikipedia</a>

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)

print(f'Accuracy: {acc}')
# Out:
# Accuracy: 0.75

# %% [markdown]
# **Precission** <br>
# Precision is the proportion of test instances that were predicted to be positive that are truly positive.

# %% [markdown]
# ![Screenshot 2025-05-30 175701.png](attachment:0e0e8ffc-10e9-4d62-849b-49cd323a7b03.png)

# %% [markdown]
# Referensi : <a href="https://en.wikipedia.org/wiki/Precision_and_recall">Wikipedia</a>

# %%
from sklearn.metrics import precision_score

prec = precision_score(y_test, y_pred)

print(f'Precission: {prec}')
# Out:
# Precission: 0.6666666666666666

# %% [markdown]
# **Recall**<br>
# Recall is the proportion of truly positive test instances that were predicted to be positive. <br>
# ![Screenshot 2025-05-30 180009.png](attachment:6e520636-91e1-4752-9c1f-865e8d12a6f1.png)<br>
# Referensi : <a href="https://en.wikipedia.org/wiki/Precision_and_recall">Wikipedia</a>

# %%
from sklearn.metrics import recall_score

rec = recall_score(y_test, y_pred)

print(f'Recall: {rec}')
# Out:
# Recall: 1.0

# %% [markdown]
# **F1 Score**<br>
# The F1 score is the harmonic mean of precision and recall<br>
# ![Screenshot 2025-05-30 180250.png](attachment:93c04fab-67be-4e57-a187-b5127b8b0f71.png)<br>
# Referensi : <a href="https://en.wikipedia.org/wiki/Precision_and_recall">Wikipedia</a>

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, y_pred)

print(f'F1-score: {f1}')
# Out:
# F1-score: 0.8

# %% [markdown]
# **Classification Report**
# - Keempat matriks di atas dapat ditampilkan menggunakan fungsi classification_report()
# - Laporan yang dihasilkan mencakup semua kelas, di mana kelas pria direpresentasikan oleh 0 dan kelas wanita direpresentasikan oleh 1
# - Nilai akurasi tidak bergantung pada kelas. Laporan ini ditujukan untuk pengklasifikasi biner, yang berarti tidak tergantung pada kelas sehingga tetap dibagi menjadi 2 kelompok nilai 0 dan 1

# %%
from sklearn.metrics import classification_report

cls_report = classification_report(y_test, y_pred)

print(f'Classification Report:\n{cls_report}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.75         4
#    macro avg       0.83      0.75      0.73         4
# weighted avg       0.83      0.75      0.73         4

# %% [markdown]
# **Matthews Correlation Coefficient (MCC)**
# - MCC is an alternative to the F1 score for measuring the performance of binary classifiers
# - A perfect classifier's MCC is 1
# - A trivial classifier that predicts randomly will score 0, and a perfectly wrong classifier will score -1 <br>
# ![Screenshot 2025-05-30 180730.png](attachment:e2583cbe-8791-4e84-bd47-3d97cc90f452.png)<br>
# Referensi : <a href="https://en.wikipedia.org/wiki/Matthews_correlation_coefficient">Wikipedia</a>

# %%
from sklearn.metrics import matthews_corrcoef

mcc = matthews_corrcoef(y_test, y_pred)

print(f'MCC: {mcc}')
# Out:
# MCC: 0.5773502691896258
